# %%
import csv
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
f=open('test.csv',encoding='utf-8')
data=csv.reader(f)
next(data)
result=[]
for row in data:
    if row[-1]!='':
        result.append(float(row[-1]))
f.close()
plt.hist(result,bins=10)
plt.show()

# %%
import csv
f=open('test2.csv',encoding='utf-8')
data=csv.reader(f)
next(data)
result=[]

for row in data:
    if row[0]!='':
        my_str=row[0]
        result=my_str[11:13] #시간 별로 나누기위해 시간들만 추출

        print(result)   #시간 다수 출력
print(result)   #시간 마지막 출력
f.close()
# Out:
# 23
# 23
# 23
# 23
# 07
# 00
# 00
# 00
# 00
# 00
# 00
# 00
# 00
# 00
# 00

# %%
with open('test2.csv',encoding='utf-8') as file:
    data=file.read()
    result=[]
    benign=data.count('BENIGN')
    error=data.count('ERROR')
    malicious=data.count('MALICIOUS')
    suspicious=data.count('SUSPICIOUS')
    total=benign+error+malicious+suspicious
    test=[benign,error,malicious,suspicious,total]
print('BENIGN 개수 :', benign)
print('ERROR 개수 :', error)
print('MALICIOUS 개수 :', malicious)
print('SUSPICIOUS 개수 :', suspicious)
print('합 개수 :', total)
fig = plt.figure(figsize=(10,10)) ## 캔버스 생성
fig.set_facecolor('white') ## 배경색 설정

#plt.hist(['benign','error','malicious','suspicious','total'],
#        bins=30,histtype='bar', color='g', edgecolor='k')
plt.hist(['benign',benign],bins=1,histtype='bar', color='g', edgecolor='k',label='benign',rwidth = 0.8)
plt.hist(['error',error],bins=1,histtype='bar', color='r', edgecolor='k',label='error',rwidth = 0.8)
plt.hist(['malicious',malicious],bins=1,histtype='bar', color='b', edgecolor='k',label='malicious',rwidth = 0.8)
plt.hist(['suspicious',suspicious],bins=1,histtype='bar', color='y', edgecolor='k',label='suspicious',rwidth = 0.8)
plt.hist(['total',total],bins=1,histtype='bar', color='skyblue', edgecolor='k',label='total',rwidth = 0.8)

plt.xlabel('Diagnosis Result')
plt.ylabel('Value')
plt.legend(loc=1)
plt.show()
# Out:
# BENIGN 개수 : 12
# ERROR 개수 : 0
# MALICIOUS 개수 : 1
# SUSPICIOUS 개수 : 1
# 합 개수 : 14
